# %%
import pandas as pd
from sklearn.ensemble import IsolationForest

class PlayerAnomalyDetector:
    
    # 1. GÖREV: Sınıfın Kurucusu (Sistem ilk açıldığında neler hazır olsun?)
    def __init__(self):
        self.model = IsolationForest(contamination=0.05,
                                     random_state=42)
        self.veri = None

    # 2. GÖREV: Veri Yükleme
    def veri_yukle(self, dosya_yolu):
        print(f"📦 Maç verileri sunucudan çekiliyor: {dosya_yolu}")
        
        data = pd.read_csv(dosya_yolu)
        self.veri = data
        print("Veri başarıyla yüklendi")
        pass

# --- TEST KODLARI (Şimdilik çalıştırmayacağız, mantığını kurman yeterli) ---
anti_cheat_sistemi = PlayerAnomalyDetector()
anti_cheat_sistemi.veri_yukle("moba_match_stats.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from sklearn.ensemble import IsolationForest
#       4 class PlayerAnomalyDetector:
#       5
#       6     # 1. GÖREV: Sınıfın Kurucusu (Sistem ilk açıldığında neler hazır olsun?)
#       7     def __init__(self):
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/__init__.py:73
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)     67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from . import (  # noqa: F401 E402
#      70     __check_build,
# ...

# %%
class PlayerAnomalyDetector:
    def __init__(self):
        self.model = IsolationForest(contamination=0.05, random_state=42)
        self.veri = None

    def veri_yukle(self, dosya_yolu):
        print(f"📦 Maç verileri sunucudan çekiliyor: {dosya_yolu}")
        self.veri = pd.read_csv(dosya_yolu)
        print("✅ Veri başarıyla yüklendi!")

    # --- YENİ GÖREVLER BAŞLIYOR ---

    # 3. GÖREV: Modeli Eğitme ve Tahmin (Hilecileri/Trolleri Avlama)
    def anomali_tespit_et(self, secilen_kolonlar):
        print("🔍 Analiz başlatılıyor...")
        
        X = self.veri[secilen_kolonlar]
        # İPUCU 1: self.veri'nin içinden sadece parametre olarak gelen 'secilen_kolonlar'ı al 
        # ve 'X' adında bir değişkene ata. (Tıpkı Pandas'ta yaptığın gibi: df[kolon_listesi])
        
        self.model.fit(X)
        # İPUCU 2: Sınıfın modeli olan 'self.model'i kullanarak bu 'X' verisini eğit (fit) 
        # ve tahminleri al (predict). Çıkan -1 ve 1'lerden oluşan listeyi 'tahminler' değişkenine ata.
        
        self.veri['Anomali_Skoru'] = self.model.predict(X)
        # İPUCU 3: self.veri tablosuna 'Anomali_Skoru' adında YENİ bir sütun ekle 
        # ve bu 'tahminler' listesini o sütuna eşitle.

    # 4. GÖREV: Sadece Şüphelileri Raporlama
    def suphelileri_getir(self):
        supheli = self.veri[self.veri['Anomali_Skoru' == -1]df['Anomali_Skoru' == 1]]

        return supheli
        # İPUCU 1: self.veri tablosunda 'Anomali_Skoru' sütunu -1 olanları filtrele (Pandas filtrelemesi).
        # İPUCU 2: Filtrelenmiş bu tabloyu 'return' ile geri döndür.
        pass

# --- TEST KODLARI (Mantığı Görmen İçin) ---
# sistem = PlayerAnomalyDetector()
# sistem.veri_yukle("moba_match_stats.csv")
# sistem.anomali_tespit_et(["KDA", "Dakika_Basi_Hasar", "Dakika_Basi_Minyon"])
# troller = sistem.suphelileri_getir()
# print(troller)
